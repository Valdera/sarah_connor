# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('credit-downsampled.csv')
dataset.head()
# Out:
#    RevolvingUtilizationOfUnsecuredLines  age  \
# 0                              1.000000   54
# 1                              0.497080   40
# 2                              0.797681   40
# 3                              0.043304   61
# 4                              0.810945   49
#
#    NumberOfTime30.59DaysPastDueNotWorse   DebtRatio  MonthlyIncome  \
# 0                                     0    0.000000         1666.0
# 1                                     0    0.510355         4200.0
# 2                                     1    0.047542         3070.0
# 3                                     0  244.000000            NaN
# 4                                     0    4.000000            NaN
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                                1                        0
# 1                                8                        0
# 2                                6                        0
# 3                               14                        0
# 4                                1                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60.89DaysPastDueNotWorse  \
# 0                             0                                     0
# 1                             2                                     0
# 2                             0                                     0
# 3                             0                                     0
# 4                             0                                     0
#
#    NumberOfDependents  Class
# 0                 0.0      0
# 1                 3.0      0
# 2                 2.0      0
# 3                 0.0      0
# 4                 0.0      0

# %%
X = dataset[["age", "DebtRatio", "MonthlyIncome", "NumberOfOpenCreditLinesAndLoans", "RevolvingUtilizationOfUnsecuredLines"]]
y = dataset.iloc[:, -1].values

# %%
X
# Out:
# array([[5.40000000e+01, 0.00000000e+00, 1.66600000e+03, 1.00000000e+00,
#         9.99999900e-01],
#        [4.00000000e+01, 5.10354677e-01, 4.20000000e+03, 8.00000000e+00,
#         4.97080234e-01],
#        [4.00000000e+01, 4.75415170e-02, 3.07000000e+03, 6.00000000e+00,
#         7.97680928e-01],
#        ...,
#        [4.60000000e+01, 3.16500000e+03,            nan, 1.30000000e+01,
#         4.66800284e-01],
#        [6.80000000e+01, 4.95975232e-01, 1.61400000e+03, 4.00000000e+00,
#         9.99999900e-01],
#        [3.40000000e+01, 4.88677581e-01, 1.02000000e+04, 1.60000000e+01,
#         2.18611666e-01]])

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(X[:, 2:3])
X[:, 2:3] = imputer.transform(X[:, 2:3])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
dataset.corr()
# Out:
#                                       RevolvingUtilizationOfUnsecuredLines  \
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.015476
# NumberOfTime30.59DaysPastDueNotWorse                             -0.003057
# DebtRatio                                                         0.029059
# MonthlyIncome                                                    -0.001177
# NumberOfOpenCreditLinesAndLoans                                  -0.011454
# NumberOfTimes90DaysLate                                          -0.002494
# NumberRealEstateLoansOrLines                                      0.008296
# NumberOfTime60.89DaysPastDueNotWorse                             -0.002150
# NumberOfDependents                                               -0.000051
# Class                                                             0.001183
#
#                                            age  \
# RevolvingUtilizationOfUnsecuredLines -0.015476
# age                                   1.000000
# NumberOfTime30.59DaysPastDueNotWorse -0.085671
# DebtRatio                             0.027887
# MonthlyIncome                         0.065300
# NumberOfOpenCreditLinesAndLoans       0.207315
# NumberOfTimes90DaysLate              -0.090174
# NumberRealEstateLoansOrLines          0.102344
# NumberOfTime60.89DaysPastDueNotWorse -0.084174
# NumberOfDependents                   -0.177935
# Class                                -0.238278
#
#                                       NumberOfTime30.59DaysPastDueNotWorse  \
# RevolvingUtilizationOfUnsecuredLines                             -0.003057
# age                                                              -0.085671
# NumberOfTime30.59DaysPastDueNotWorse                              1.000000
# DebtRatio                                                        -0.010446
# MonthlyIncome                                                    -0.027164
# NumberOfOpenCreditLinesAndLoans                                  -0.120932
# NumberOfTimes90DaysLate                                           0.988550
# NumberRealEstateLoansOrLines                                     -0.062873
# NumberOfTime60.89DaysPastDueNotWorse                              0.992217
# NumberOfDependents                                               -0.024292
# Class                                                             0.120902
#
#                                       DebtRatio  MonthlyIncome  \
# RevolvingUtilizationOfUnsecuredLines   0.029059      -0.001177
# age                                    0.027887       0.065300
# NumberOfTime30.59DaysPastDueNotWorse  -0.010446      -0.027164
# DebtRatio                              1.000000      -0.040021
# MonthlyIncome                         -0.040021       1.000000
# NumberOfOpenCreditLinesAndLoans        0.053654       0.133733
# NumberOfTimes90DaysLate               -0.013016      -0.032564
# NumberRealEstateLoansOrLines           0.090579       0.173106
# NumberOfTime60.89DaysPastDueNotWorse  -0.011825      -0.029555
# NumberOfDependents                    -0.027823       0.059460
# Class                                 -0.018252      -0.053739
#
#                                       NumberOfOpenCreditLinesAndLoans  \
# RevolvingUtilizationOfUnsecuredLines                        -0.011454
# age                                                          0.207315
# NumberOfTime30.59DaysPastDueNotWorse                        -0.120932
# DebtRatio                                                    0.053654
# MonthlyIncome                                                0.133733
# NumberOfOpenCreditLinesAndLoans                              1.000000
# NumberOfTimes90DaysLate                                     -0.151845
# NumberRealEstateLoansOrLines                                 0.471721
# NumberOfTime60.89DaysPastDueNotWorse                        -0.136677
# NumberOfDependents                                           0.036271
# Class                                                       -0.063032
#
#                                       NumberOfTimes90DaysLate  \
# RevolvingUtilizationOfUnsecuredLines                -0.002494
# age                                                 -0.090174
# NumberOfTime30.59DaysPastDueNotWorse                 0.988550
# DebtRatio                                           -0.013016
# MonthlyIncome                                       -0.032564
# NumberOfOpenCreditLinesAndLoans                     -0.151845
# NumberOfTimes90DaysLate                              1.000000
# NumberRealEstateLoansOrLines                        -0.080716
# NumberOfTime60.89DaysPastDueNotWorse                 0.993458
# NumberOfDependents                                  -0.028275
# Class                                                0.112177
#
#                                       NumberRealEstateLoansOrLines  \
# RevolvingUtilizationOfUnsecuredLines                      0.008296
# age                                                       0.102344
# NumberOfTime30.59DaysPastDueNotWorse                     -0.062873
# DebtRatio                                                 0.090579
# MonthlyIncome                                             0.173106
# NumberOfOpenCreditLinesAndLoans                           0.471721
# NumberOfTimes90DaysLate                                  -0.080716
# NumberRealEstateLoansOrLines                              1.000000
# NumberOfTime60.89DaysPastDueNotWorse                     -0.072112
# NumberOfDependents                                        0.084003
# Class                                                    -0.015253
#
#                                       NumberOfTime60.89DaysPastDueNotWorse  \
# RevolvingUtilizationOfUnsecuredLines                             -0.002150
# age                                                              -0.084174
# NumberOfTime30.59DaysPastDueNotWorse                              0.992217
# DebtRatio                                                        -0.011825
# MonthlyIncome                                                    -0.029555
# NumberOfOpenCreditLinesAndLoans                                  -0.136677
# NumberOfTimes90DaysLate                                           0.993458
# NumberRealEstateLoansOrLines                                     -0.072112
# NumberOfTime60.89DaysPastDueNotWorse                              1.000000
# NumberOfDependents                                               -0.029489
# Class                                                             0.097699
#
#                                       NumberOfDependents     Class
# RevolvingUtilizationOfUnsecuredLines           -0.000051  0.001183
# age                                            -0.177935 -0.238278
# NumberOfTime30.59DaysPastDueNotWorse           -0.024292  0.120902
# DebtRatio                                      -0.027823 -0.018252
# MonthlyIncome                                   0.059460 -0.053739
# NumberOfOpenCreditLinesAndLoans                 0.036271 -0.063032
# NumberOfTimes90DaysLate                        -0.028275  0.112177
# NumberRealEstateLoansOrLines                    0.084003 -0.015253
# NumberOfTime60.89DaysPastDueNotWorse           -0.029489  0.097699
# NumberOfDependents                              1.000000  0.084530
# Class                                           0.084530  1.000000

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[1509  990]
#  [ 985 1529]]
# 0.6060243367245163

# %%
y_pred_train = classifier.predict(X_train)
ck = confusion_matrix(y_train, y_pred_train)
accuracy_score(y_train, y_pred_train)
# Out:
# 0.5999069087040362
